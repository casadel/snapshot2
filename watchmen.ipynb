# %% [markdown]
# ##The WATCHMEN

# %% [markdown]
# IPRs

# %%
watchmen_iprs = [
    
    # PTAB
    {
       # Lupin Ltd v. HZNP '966 patent; institution decision due 10/6
        'name': 'IPR2017-01160',
        'url': 'https://ptab.uspto.gov/ptabe2e/rest/petitions/1463545/documents?availability=PUBLIC&cacheFix=',
        'sound': 'C:\\Windows\Media\Hznp.wav',
        'type': 'json',
        'delay': 10,
        'dec_types': ['Decision Granting Institution', 'Decision Denying Institution', 'Settlement Before Institution']
    },
    
    {
         # REGN AMGN dupixent preliminary, institution decision due 10/6
        'name': 'IPR2017-01129',
        'url': 'https://ptab.uspto.gov/ptabe2e/rest/petitions/1485794/documents?availability=PUBLIC&cacheFix=',
        'sound': 'C:\\Windows\Media\Regn.wav',
        'type': 'json',
        'dec_types': ['Decision Granting Institution', 'Decision Denying Institution', 'Settlement Before Institution']
    },
    
    {
       # Teva v. LLY '209 patent; decision due 10/6
        'name': 'IPR2016-01340',
        'url': 'https://ptab.uspto.gov/ptabe2e/rest/petitions/1464143/documents?availability=PUBLIC&cacheFix=',
        'sound': 'C:\\Windows\Media\Lly.wav',
        'type': 'json',
        'delay': 10
    },
    
    {
       # Teva v. LLY '209 patent; decision due 10/6
        'name': 'IPR2016-01343',
        'url': 'https://ptab.uspto.gov/ptabe2e/rest/petitions/1462941/documents?availability=PUBLIC&cacheFix=',
        'sound': 'C:\\Windows\Media\Lly.wav',
        'type': 'json',
        'delay': 10
    },
    
    {
       # Teva v. LLY '209 patent; decision due 10/6
        'name': 'IPR2016-01341',
        'url': 'https://ptab.uspto.gov/ptabe2e/rest/petitions/1464261/documents?availability=PUBLIC&cacheFix=',
        'sound': 'C:\\Windows\Media\Lly.wav',
        'type': 'json',
        'delay': 10
    },
    
    {
       # Aurobindo v. AZN patent re44186; decision due 10/21
        'name': 'IPR2016-01341',
        'url': 'https://ptab.uspto.gov/ptabe2e/rest/petitions/1464261/documents?availability=PUBLIC&cacheFix=',
        'sound': 'C:\\Windows\Media\Azn.wav',
        'type': 'json',
        'delay': 10
    },
    
    {
       # Lupin Ltd v. HZNP '278 patent; institution decision due 10/24
        'name': 'IPR2017-01159',
        'url': 'https://ptab.uspto.gov/ptabe2e/rest/petitions/1486074/documents?availability=PUBLIC&cacheFix=',
        'sound': 'C:\\Windows\Media\Hznp.wav',
        'type': 'json',
        'delay': 10,
        'dec_types': ['Decision Granting Institution', 'Decision Denying Institution', 'Settlement Before Institution']
    },
    
    {
       # Wockhardt v. LLY '209 patent; decision due 11/18
        'name': 'IPR2016-01335',
        'url': 'https://ptab.uspto.gov/ptabe2e/rest/petitions/1463435/documents?availability=PUBLIC&cacheFix=',
        'sound': 'C:\\Windows\Media\Lly.wav',
        'type': 'json',
        'delay': 10
    },
    
    {
       # Wockhardt v. LLY '209 patent; decision due 11/18
        'name': 'IPR2016-01337',
        'url': 'https://ptab.uspto.gov/ptabe2e/rest/petitions/1463548/documents?availability=PUBLIC&cacheFix=',
        'sound': 'C:\\Windows\Media\Lly.wav',
        'type': 'json',
        'delay': 10
    },
    
    {
       # Wockhardt v. LLY '209 patent; decision due 11/21
        'name': 'IPR2016-01393',
        'url': 'https://ptab.uspto.gov/ptabe2e/rest/petitions/1463563/documents?availability=PUBLIC&cacheFix=',
        'sound': 'C:\\Windows\Media\Lly.wav',
        'type': 'json',
        'delay': 10
    },
    
    {
       # Aurobindo v. AZN patent re44186; decision due 11/22
        'name': 'IPR2016-01104',
        'url': 'https://ptab.uspto.gov/ptabe2e/rest/petitions/1464280/documents?availability=PUBLIC&cacheFix=',
        'sound': 'C:\\Windows\Media\Azn.wav',
        'type': 'json',
        'delay': 10
    },
    
    {
       # Luye v. ALKS '061 patent; decision due 11/30
        'name': 'IPR2016-01096',
        'url': 'https://ptab.uspto.gov/ptabe2e/rest/petitions/1463545/documents?availability=PUBLIC&cacheFix=',
        'sound': 'C:\\Windows\Media\Alks.wav',
        'type': 'json',
        'delay': 10
    },
    
]
